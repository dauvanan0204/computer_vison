# %%
    # Chuyen tu anh mau RGB sang anh xam
    # Uu diem:
    # - giam chi phi tinh toan
    # - tap trung vao do sang
    # - tiet kiem dung luong luu tru
    # - giam nhieu
    # - de dang hieu va xu ly
    # Nhuoc diem:
    # - co the lam mat mat thong tin ve mau sac
from PIL import Image
from ImageTool import *
from IPython.display import display

# Path of image
myPath = 'D:/Python/computervision/image/01/1.jpg'
# dir = 'D:/Python/computervision/image/01'
# Read image
img = load_image(myPath)
display(img)

# Chuyen tu ang rgb sang anh xam
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# <PIL.Image.Image image mode=L size=500x332>

# %%
# Phan RGB thanh 3 tang mau khac nhau
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=500x332>
# <PIL.Image.Image image mode=L size=500x332>
# <PIL.Image.Image image mode=L size=500x332>

# %%
# Tron anh
merged_image = Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x332>
