# %%
# Giới thiệu bộ lọc đạo hàm
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

# Đọc ảnh
image_path = 'D:/Python/computervision/image/01/img_avg_1.jpg'
image = Image.open(image_path)

# Ảnh xám
gray_image = image.convert('L')

# Chuyển ảnh xám về mảng
image_a = np.array(gray_image)

# Bo loc Sobel

# Tính gradient theo hướng x
gradient_x = ndimage.sobel(image_a, axis=0, mode='constant')

# Tính gradient theo hướng y
gradient_y = ndimage.sobel(image_a, axis=1, mode='constant')

# Hiển thị ảnh
fig, axs = plt.subplots(2,2, figsize=(10, 8))

plt.subplot(2,2,1)
plt.imshow(gray_image, cmap='gray')
plt.title('Ảnh xám gốc')

plt.subplot(2,2,2)
plt.imshow(gradient_x, cmap='gray')
plt.title('Ảnh xám tinh gradient theo x')

plt.subplot(2,2,3)
plt.imshow(gradient_y, cmap='gray')
plt.title('Ảnh xám tinh gradient theo y')

plt.show()

# %%
# Bo loc Prewitt
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

# Đọc ảnh
image_path = 'D:/Python/computervision/image/01/img_avg_1.jpg'
image = Image.open(image_path)

# Ảnh xám
gray_image = image.convert('L')

# Chuyển ảnh xám về mảng
image_a = np.array(gray_image)

# Tính gradient theo hướng x (đạo hàm riêng theo x) bằng mặt nạ Prewitt x
gradient_x = ndimage.convolve(image_a, np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]]))

# Tính gradient theo hướng y (đạo hàm riêng theo y) bằng mặt nạ Prewitt y
gradient_y = ndimage.convolve(image_a, np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]]))

# Tính biên độ gradient
gradient_magnitude = np.sqrt(gradient_x**2 + gradient_y**2)

# Hiển thị ảnh
fig, axs = plt.subplots(2,1, figsize=(10, 8))

plt.subplot(2,1,1)
plt.imshow(gray_image, cmap='gray')
plt.title('Ảnh xám gốc')

plt.subplot(2,1,2)
plt.imshow(gradient_magnitude, cmap='gray')
plt.title('Ảnh xám gốc')

plt.show()
