# %%
from PIL import Image
from ImageTool import *
from IPython.display import display

# Path of image
myPath = 'D:/Python/computervision/image/01/1.jpg'
# dir = 'D:/Python/computervision/image/01'
# Read image
img = load_image(myPath)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>

# %%
# Cut image
# Dinh vi khu vuc cut
region = (100, 75, 175, 160)
# image cut
croppedImage = img.crop(region)
display(croppedImage)
# croppedImage = dir + '/new01.JPG'
# img.save(croppedImage)
# Out:
# <PIL.Image.Image image mode=RGB size=75x85>

# %%
#Paste
paste_position = (250, 250)
img.paste(croppedImage, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
