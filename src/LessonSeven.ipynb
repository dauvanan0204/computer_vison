# %%
import matplotlib as matplotlib
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Duong dan anh
my_path = 'D:/Python/computervision/image/01/1.jpg'
# Doc anh va hien thi
im = Image.open(my_path)
# display(im)
plt.imshow(im)

# %%
# Ve do thi co ban
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color = 'red')
plt.title('Bieu do')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color = 'red')
plt.title('Bieu do')
plt.axis('off') # tat he truc toa do
plt.show()

# %%
# Ve tren hinh anh
im = Image.open(my_path)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(im)
plt.plot(x, y, 'r*') # Danh dau cac diem
plt.plot(x, y, 'ys:')
plt.show()
